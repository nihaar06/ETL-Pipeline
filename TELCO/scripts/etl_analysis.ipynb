# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('..//data//staged//churn_staged.csv')

# %%
df.head()
# Out:
#    SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 0              0     Yes         No       1           No  No phone service
# 1              0      No         No      34          Yes                No
# 2              0      No         No       2          Yes                No
# 3              0      No         No      45           No  No phone service
# 4              0      No         No       2          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 0             DSL             No          Yes               No  ...
# 1             DSL            Yes           No              Yes  ...
# 2             DSL            Yes          Yes               No  ...
# 3             DSL            Yes           No              Yes  ...
# 4     Fiber optic             No           No               No  ...
#
#   PaperlessBilling              PaymentMethod MonthlyCharges TotalCharges  \
# ...

# %%
df.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
print("Churn percentage:",(df[df['Churn']=='Yes'].shape[0]/df['Churn'].shape[0])*100)
# Out:
# Churn percentage: 26.536987079369588

# %%
print("Count of tenure groups:",df['tenure_group'].value_counts())
# Out:
# Count of tenure groups: tenure_group
# New         2069
# Regular     1923
# Loyal       1568
# Champion    1483
# Name: count, dtype: int64

# %%
df[['Churn','tenure_group']].head()
# Out:
#   Churn tenure_group
# 0    No          New
# 1    No      Regular
# 2   Yes          New
# 3    No        Loyal
# 4   Yes          New

# %%
print("Internet service distribution:\n",df['InternetService'].value_counts())
# Out:
# Internet service distribution:
#  InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
# Percentage of customers having internet service:
#  0.0

# %%
print("Average monthly charges per contract:\n",df.groupby("Contract")['MonthlyCharges'].mean())
# Out:
# Average monthly charges per contract:
#  Contract
# Month-to-month    66.398490
# One year          65.048608
# Two year          60.770413
# Name: MonthlyCharges, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['TotalCharges'],bins=10)
plt.xlabel("Total Charges")
# Out:
# Text(0.5, 0, 'Total Charges')

# %%
plt.bar(df['Contract'].value_counts().index, df['Contract'].value_counts())
# Out:
# <BarContainer object of 3 artists>
